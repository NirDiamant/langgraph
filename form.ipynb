# %% [markdown]
# ---
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 20px; margin: 30px 0; color: white; font-family: 'Segoe UI', system-ui, sans-serif; box-shadow: 0 15px 35px rgba(102, 126, 234, 0.3);">
#
# <div align="center">
#
# # 🚀 Help Improve This Tutorial
#
# ### **Agent Memory with Redis**
# *Your feedback improves this tutorial and gives **Redis** valuable insights*
#
# </div>
#
# ---
#
# <form action="https://docs.google.com/forms/d/e/1FAIpQLSeCDpJqqI-cx3wG6M2TkWqF27AD_qqSkpHqT4qPzdjWam2B_A/formResponse" method="POST" target="hiddenFrame" style="margin-top: 20px;">
#
# <div style="background: rgba(255,255,255,0.15); padding: 20px; border-radius: 15px; margin-bottom: 20px;">
#
# <h3>📚 Rate this tutorial:</h3>
# <div align="center" style="margin: 15px 0;">
# <label style="display: inline-block; margin: 5px; padding: 12px 20px; background: rgba(255,255,255,0.2); border-radius: 25px; font-weight: 600; cursor: pointer;">
# <input type="radio" name="entry.1442236884" value="5" style="margin-right: 8px;"> 🔥 Amazing
# </label>
# <label style="display: inline-block; margin: 5px; padding: 12px 20px; background: rgba(255,255,255,0.2); border-radius: 25px; font-weight: 600; cursor: pointer;">
# <input type="radio" name="entry.1442236884" value="4" style="margin-right: 8px;"> 👍 Great
# </label>
# <label style="display: inline-block; margin: 5px; padding: 12px 20px; background: rgba(255,255,255,0.2); border-radius: 25px; font-weight: 600; cursor: pointer;">
# <input type="radio" name="entry.1442236884" value="3" style="margin-right: 8px;"> 👌 Good
# </label>
# <label style="display: inline-block; margin: 5px; padding: 12px 20px; background: rgba(255,255,255,0.2); border-radius: 25px; font-weight: 600; cursor: pointer;">
# <input type="radio" name="entry.1442236884" value="2" style="margin-right: 8px;"> 🤔 Needs Work
# </label>
# </div>
#
# <h3>🚀 Will you try Redis after this?</h3>
# <div align="center" style="margin: 15px 0;">
# <label style="display: inline-block; margin: 5px; padding: 10px 18px; background: rgba(255,255,255,0.2); border-radius: 20px; font-weight: 600; cursor: pointer;">
# <input type="radio" name="entry.1525387088" value="definitely" style="margin-right: 8px;"> 💯 Definitely
# </label>
# <label style="display: inline-block; margin: 5px; padding: 10px 18px; background: rgba(255,255,255,0.2); border-radius: 20px; font-weight: 600; cursor: pointer;">
# <input type="radio" name="entry.1525387088" value="probably" style="margin-right: 8px;"> 👍 Probably
# </label>
# <label style="display: inline-block; margin: 5px; padding: 10px 18px; background: rgba(255,255,255,0.2); border-radius: 20px; font-weight: 600; cursor: pointer;">
# <input type="radio" name="entry.1525387088" value="maybe" style="margin-right: 8px;"> 🤷 Maybe
# </label>
# <label style="display: inline-block; margin: 5px; padding: 10px 18px; background: rgba(255,255,255,0.2); border-radius: 20px; font-weight: 600; cursor: pointer;">
# <input type="radio" name="entry.1525387088" value="no" style="margin-right: 8px;"> ❌ No
# </label>
# </div>
#
# </div>
#
# <div style="background: rgba(255,255,255,0.15); padding: 20px; border-radius: 15px; margin-bottom: 20px;">
#
# <h3>💭 Your feedback (optional):</h3>
# <textarea name="entry.929880981" placeholder="What was confusing? What's missing? Any suggestions for improvement?" style="width: 100%; padding: 10px; border-radius: 8px; border: none; background: white; color: #333; font-family: inherit; min-height: 80px; box-sizing: border-box; margin-bottom: 15px;"></textarea>
#
# <h3>👤 Your background (optional):</h3>
# <select name="entry.81513512" style="width: 100%; padding: 10px; border-radius: 8px; border: none; background: white; color: #333; font-family: inherit; box-sizing: border-box;">
# <option value="">Select your role...</option>
# <option value="Student">Student</option>
# <option value="Developer">Software Developer</option>
# <option value="Data Scientist">Data Scientist</option>
# <option value="ML Engineer">ML Engineer</option>
# <option value="Researcher">Researcher</option>
# <option value="Other">Other</option>
# </select>
#
# </div>
#
# <div align="center">
# <button type="submit" style="background: linear-gradient(45deg, #ff6b6b, #4ecdc4); color: white; padding: 15px 40px; border: none; border-radius: 25px; font-size: 16px; font-weight: 700; cursor: pointer; box-shadow: 0 6px 20px rgba(255,107,107,0.4);">
# 🚀 Submit Feedback
# </button>
# </div>
#
# </form>
#
# <div align="center" style="font-size: 12px; opacity: 0.8; margin-top: 20px;">
# <strong>🏆 Community Impact:</strong> <em>Your feedback shapes AI education for developers worldwide</em><br>
# <em>📊 Individual responses kept private • Used to improve tutorials and products</em>
# </div>
#
# </div>
#
# <iframe name="hiddenFrame" style="display: none;"></iframe>
#
# ---
