# %% [markdown]
# graph TD
#     subgraph INPUT["📥 INPUT SOURCES"]
#         USER[👤 Users]
#         WEB[🌐 Web]
#         DOCS[📄 Documents]
#         APIS[🔌 APIs]
#     end
#
#     subgraph INTEL["🧠 DATA & INTELLIGENCE"]
#         BD["<b>🕷️ BRIGHT DATA</b><br/>Web Scraping at Scale"]
#         CAI["<b>📚 CONTEXTUAL AI</b><br/>RAG & Knowledge Platform"]
#         TAV["<b>🔍 TAVILY</b><br/>Real-time Web Search"]
#         AB["<b>🌏 ANCHOR BROWSER</b><br/>Browser Automation"]
#     end
#
#     subgraph PROCESS["⚙️ AGENT FRAMEWORKS"]
#         ARC["<b>🎮 ARCADE</b><br/>Multi-user Tool Calling"]
#         POR["<b>🏗️ PORTIA</b><br/>Full-stack Framework"]
#         LG["<b>📊 LANGGRAPH</b><br/>Stateful Workflows"]
#         CP["<b>🤝 CORAL PROTOCOL</b><br/>Multi-agent Systems"]
#     end
#
#     subgraph MEMORY["💾 MEMORY & STATE"]
#         RED["<b>🔴 REDIS</b><br/>Dual Memory System"]
#         VEC[Vector Storage]
#     end
#
#     subgraph SECURITY["🛡️ SECURITY & MONITORING"]
#         QF["<b>🔥 QUALIFIRE</b><br/>Guardrails & Observability"]
#         SEC[Additional Security]
#     end
#
#     subgraph INFRA["🚀 INFRASTRUCTURE"]
#         RP["<b>⚡ RUNPOD</b><br/>GPU Infrastructure"]
#         DEPLOY[Deployment Tools]
#     end
#
#     subgraph OUTPUT["📤 OUTPUTS"]
#         UI[🖥️ UI]
#         API[🔗 API]
#         MSG[💬 Messages]
#     end
#
#     USER --> POR
#     USER --> ARC
#     WEB --> BD
#     WEB --> TAV
#     DOCS --> CAI
#     APIS --> ARC
#
#     BD --> LG
#     CAI --> POR
#     TAV --> LG
#     AB --> BD
#
#     ARC --> CP
#     POR --> RED
#     LG --> RED
#     CP --> RED
#
#     RED --> VEC
#     RED --> QF
#
#     QF --> RP
#     RP --> API
#     POR --> UI
#     CP --> MSG
#
#     style BD fill:#4CAF50,color:#fff
#     style CAI fill:#2196F3,color:#fff
#     style ARC fill:#9C27B0,color:#fff
#     style POR fill:#FF9800,color:#fff
#     style RED fill:#F44336,color:#fff
#     style CP fill:#00BCD4,color:#fff
#     style AB fill:#8BC34A,color:#fff
#     style TAV fill:#FFC107
#     style QF fill:#E91E63,color:#fff
#     style RP fill:#673AB7,color:#fff
#     style LG fill:#795548,color:#fff
